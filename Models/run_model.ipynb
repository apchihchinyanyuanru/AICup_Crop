# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load package
import pandas as pd
import numpy as np

# %%
# load the model
import joblib
filename = '/content/drive/MyDrive/ISA_DM/Result/model/lightGBM_model_2.sav'

gbm_final = joblib.load(filename)
gbm_final
# Out:
# RandomForestClassifier()

# %%
# load the numpy file
X3 = np.load('/content/drive/MyDrive/ISA_DM/Result/model feed in features/X3_xgb3_lgbm2.npy')
X3.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-5cfc09e9fdfa> in <module>()
#       1 # load the numpy file
# ----> 2 X3 = np.load('/content/drive/MyDrive/ISA_DM/Result/full_tired.npy')
#       3 X3.shape
#
# NameError: name 'np' is not defined

# %%
# predict stage 3
# NOTICE X3 in different feature data are different
Y3 = gbm_final.predict(X3)

# %%
np.save('/content/drive/MyDrive/ISA_DM/Result/final/Y3_xgb3_rf3',Y3)
Y3.shape
# Out:
# (972,)

# %%
reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
